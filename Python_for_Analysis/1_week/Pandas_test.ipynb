# %%
import pandas as pd
from geopy.distance import vincenty
import datetime

# %%
df = pd.read_csv("data/201809-citibike-tripdata.csv")
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1635  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1           132  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2          3337  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3           436  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4          8457  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
#
#    start station id               start station name  start station latitude  \
# 0             252.0     MacDougal St & Washington Sq               40.732264
# 1             314.0  Cadman Plaza West & Montague St               40.693830
# 2            3142.0                  1 Ave & E 62 St               40.761227
# 3             308.0          St James Pl & Oliver St               40.713079
# 4             345.0                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# ...

# %% [markdown]
# $1.$

# %%
df.shape
# Out:
# (1877884, 15)

# %% [markdown]
# $2.$

# %%
df.tripduration.mean() / 60
# Out:
# 16.125248648656324

# %% [markdown]
# $3.$

# %%
df[df["start station id"] == df["end station id"]].shape[0]
# Out:
# 41364

# %% [markdown]
# $4.$

# %%
df.bikeid.value_counts().idxmax()
# Out:
# 33875

# %% [markdown]
# $5.$

# %%
df.groupby("bikeid")["tripduration"].mean().idxmax()
# Out:
# 17548

# %% [markdown]
# $6.$

# %%
df["start station id"].isna().sum()
# Out:
# 716

# %% [markdown]
# $7.$

# %%
df.groupby("usertype")["tripduration"].mean() / 60
# Out:
# usertype
# Customer      33.415379
# Subscriber    13.332348
# Name: tripduration, dtype: float64

# %% [markdown]
# $8.$

# %%
m = df[df["start station id"] != df["end station id"]]

# %%
m = m[m["start station id"].notna()]

# %%
m = m[[
    "start station latitude", 
    "start station longitude", 
    "end station latitude", 
    "end station longitude"
]]

m.apply(lambda x: vincenty((x[0], x[1]), (x[2], x[3])).km, axis = 1).mean()
# Out:
# 1.8500554756408196

# %% [markdown]
# $9.$

# %%
df["starttime"] = pd.to_datetime(df["starttime"])

# %%
d = df[
    (df["starttime"].dt.time <= datetime.time(hour = 20)) 
    & 
    (df["starttime"].dt.time >= datetime.time(hour = 18))
]

# %%
d["start station id"].value_counts().idxmax()
# Out:
# 519.0

# %% [markdown]
# $10.$

# %%
df["stoptime"] = pd.to_datetime(df["stoptime"])

# %%
d = df["end station id"][
    (df["stoptime"].dt.time <= datetime.time(hour = 10)) 
    & 
    (df["stoptime"].dt.time >= datetime.time(hour = 6))
]

# %%
(d == 3140).sum() != 0
# Out:
# True

# %%
(d == 3106).sum() != 0
# Out:
# True

# %%
(d == 3116).sum() != 0
# Out:
# True

# %%
(d == 369).sum() != 0
# Out:
# True
